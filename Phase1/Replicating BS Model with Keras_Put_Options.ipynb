# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import time

from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import r2_score

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras import models
from tensorflow.keras import layers

from tensorflow.keras.wrappers.scikit_learn import KerasRegressor

from keras_tuner import RandomSearch

np.set_printoptions(precision = 3, suppress = True)

# %%
sim_data = pd.read_csv("sim_data_put.csv")
df = sim_data.drop(['Unnamed: 0'], axis = 1)
df.head()
# Out:
#    Stock price  Strike price  Maturity  Dividend rate  Risk free rate  \
# 0   455.863983    454.829686     356.0       0.020148        0.019092
# 1   183.299649    190.987592     481.0       0.005972        0.019851
# 2   154.969757    152.865485      34.0       0.001171        0.012583
# 3   374.253746    361.495397     110.0       0.027602        0.022187
# 4   466.573790    469.618548     927.0       0.010858        0.020669
#
#    Volatility  Put Price
# 0    0.880006   0.508178
# 1    0.555565   0.013622
# 2    0.647748  92.505717
# 3    0.314800  29.164941
# 4    0.742902   0.000002

# %%
df.describe()
# Out:
#          Stock price   Strike price       Maturity  Dividend rate  \
# count  300000.000000  300000.000000  300000.000000   3.000000e+05
# mean      328.746889     328.755664     546.860933   1.502393e-02
# std       185.844014     185.523154     315.444242   8.662222e-03
# min         6.674963       7.000585       1.000000   1.019712e-07
# 25%       167.623932     167.693784     274.000000   7.518604e-03
# 50%       328.820308     329.016320     546.000000   1.504665e-02
# 75%       489.267113     489.824457     820.000000   2.251980e-02
# max       682.372745     649.988411    1094.000000   2.999999e-02
#
#        Risk free rate     Volatility     Put Price
# count   300000.000000  300000.000000  3.000000e+05
# mean         0.020000       0.475127  1.134410e+01
# std          0.005771       0.245260  3.822157e+01
# min          0.010000       0.050000  2.933767e-80
# 25%          0.015009       0.262613  2.230707e-05
# 50%          0.019999       0.475230  9.541800e-03
# 75%          0.024993       0.687537  1.390285e+00
# max          0.030000       0.899999  4.930816e+02

# %%
X = df[df.columns.values[:-1]]
y = df['Put Price']

X_train, X_test, y_train, y_test = train_test_split(X.copy(), y, test_size = 0.2, random_state = 123)
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((240000, 6), (60000, 6), (240000,), (60000,))

# %%
# Standardize the features
scalerX = MinMaxScaler().fit(X_train)
X_train = pd.DataFrame(scalerX.transform(X_train), columns = X.columns.values) 
X_test = pd.DataFrame(scalerX.transform(X_test), columns = X.columns.values) 

scalery = MinMaxScaler().fit(y_train.values.reshape(-1, 1))
y_train = scalery.transform(y_train.values.reshape(-1, 1))
y_test = scalery.transform(y_test.values.reshape(-1, 1))

# %%
np.random.seed(123)
tf.random.set_seed(123)

# %%
def plot_loss(history):
    plt.figure(figsize = (8,6))
    plt.plot(history.history['loss'], label = 'loss')
    plt.plot(history.history['val_loss'], label = 'val_loss')
    plt.xlabel('Epoch')
    plt.ylabel('loss')
    plt.legend()
    plt.grid(True)
    
def plot_time(time):
    print('The total training time is {} seconds.'.format(np.round(np.sum(time), 1)))
    plt.figure(figsize = (8,6))
    plt.plot(np.arange(1, len(time) + 1), time)
    plt.xlabel('Epoch')
    plt.ylabel('Time for each epoch')
    plt.grid(True)

# %%
class TimeHistory(tf.keras.callbacks.Callback):
    def on_train_begin(self, logs = {}):
        self.times = []

    def on_epoch_begin(self, batch, logs = {}):
        self.epoch_time_start = time.time()

    def on_epoch_end(self, batch, logs = {}):
        self.times.append(time.time() - self.epoch_time_start)

# %% [markdown]
# ## Robert Culkin & Sanjiv R. Das's ANN

# %%
learning_rate = [1e-3, 1e-4, 1e-5]
History = []
times = []
earlyStop = tf.keras.callbacks.EarlyStopping(monitor = 'loss', patience = 3)
for lr in learning_rate:
    model = models.Sequential()
    # Input layer
    model.add(layers.Dense(units = 6))

    # first layer
    model.add(layers.Dense(units = 100, activation = "ELU"))
    model.add(layers.Dropout(0.25))

    # second layer
    model.add(layers.Dense(units = 100, activation = "ELU"))
    model.add(layers.Dropout(0.25))

    # third layer
    model.add(layers.Dense(units = 100, activation = "ELU"))
    model.add(layers.Dropout(0.25))

    # fourth layer
    model.add(layers.Dense(units = 100, activation = "ELU"))
    model.add(layers.Dropout(0.25))

    # Output layer
    model.add(layers.Dense(units = 1, activation = "exponential"))

    model.compile(
        optimizer = keras.optimizers.Adam(learning_rate = lr), loss = "mean_squared_error"
    )
    
    time_callback = TimeHistory()

    history = model.fit(X_train, 
        y_train, 
        epochs = 100, 
        verbose = 0,
        callbacks = [earlyStop, time_callback],
        validation_split = 0.2)
    BSNN_train_pred = model.predict(X_train)
    BSNN_test_pred = model.predict(X_test)
    print('When the learning rate is', lr)
    print("The training R squared for Robert Culkin & Sanjiv R. Das's model is", 
          np.round(r2_score(y_train, BSNN_train_pred), 4))
    print("The testing R squared for Robert Culkin & Sanjiv R. Das's model is", 
          np.round(r2_score(y_test, BSNN_test_pred), 4))
    print('-------------------------------------------------------------------')
    History.append(history)
    times.append(time_callback.times)
# Out:
# When the learning rate is 0.001
# The training R squared for Robert Culkin & Sanjiv R. Das's model is 0.9802
# The testing R squared for Robert Culkin & Sanjiv R. Das's model is 0.9801
# -------------------------------------------------------------------
# When the learning rate is 0.0001
# The training R squared for Robert Culkin & Sanjiv R. Das's model is 0.9925
# The testing R squared for Robert Culkin & Sanjiv R. Das's model is 0.9927
# -------------------------------------------------------------------
# When the learning rate is 1e-05
# The training R squared for Robert Culkin & Sanjiv R. Das's model is 0.8752
# The testing R squared for Robert Culkin & Sanjiv R. Das's model is 0.8793
# -------------------------------------------------------------------

# %% [markdown]
# ### With learning rate 1e-3

# %%
plot_loss(History[0])
plot_time(times[0])
# Out:
# The total training time is 106.2 seconds.

# %% [markdown]
# ### With learning rate 1e-4

# %%
plot_loss(History[1])
plot_time(times[1])
# Out:
# The total training time is 319.9 seconds.

# %% [markdown]
# ### With learning rate 1e-5

# %%
plot_loss(History[2])
plot_time(times[2])
# Out:
# The total training time is 103.9 seconds.

# %% [markdown]
# ## Gridsearch

# %%
def build_model():
    model = models.Sequential()
    # Input layer
    model.add(layers.Dense(units = 6))

    # first layer
    model.add(layers.Dense(units = 100, activation = "ELU"))
    model.add(layers.Dropout(0.25))

    # second layer
    model.add(layers.Dense(units = 100, activation = "ELU"))
    model.add(layers.Dropout(0.25))

    # third layer
    model.add(layers.Dense(units = 100, activation = "ELU"))
    model.add(layers.Dropout(0.25))

    # fourth layer
    model.add(layers.Dense(units = 100, activation = "ELU"))
    model.add(layers.Dropout(0.25))

    # Output layer
    model.add(layers.Dense(units = 1,activation = "exponential"))

    model.compile(
        optimizer = keras.optimizers.Adam(learning_rate = 1e-4), 
        loss = "mean_squared_error"
    )
    return model

# %%
# Hyperparameters tuning 
ANN = KerasRegressor(build_fn = build_model)
batch_size = [64, 128]
epochs = [5]

# define grid search
grid = dict(batch_size = batch_size, 
            epochs = epochs)
grid_search = GridSearchCV(estimator = ANN, 
                           param_grid = grid, 
                           cv = 3, 
                           scoring = 'r2',
                           error_score = 0)
ANN_cv = grid_search.fit(X_train, y_train, callbacks = [earlyStop], verbose = 0)

# %%
for i in range(2):
    print('Parameters',ANN_cv.cv_results_['params'][i])
    print('Mean fitting time is', np.round(ANN_cv.cv_results_['mean_fit_time'][i], 4))
    print('In-sample r squared is', np.round(ANN_cv.cv_results_['mean_test_score'][i], 4))
    print('------------------------------------------')
# Out:
# Parameters {'batch_size': 64, 'epochs': 5}
# Mean fitting time is 13.2147
# In-sample r squared is 0.8602
# ------------------------------------------
# Parameters {'batch_size': 128, 'epochs': 5}
# Mean fitting time is 7.3952
# In-sample r squared is 0.7887
# ------------------------------------------

# %%
# tuner = RandomSearch(
#     build_model,
#     objective = "mean_squared_error",
#     max_trials = 5,
#     seed = 123,
#     overwrite = True,
#     directory = "/Users/gaojinglun/Desktop/RSG"
# )
# callback = tf.keras.callbacks.EarlyStopping(monitor = 'loss', patience = 3)
# tuner.search(X_train, y_train, 
#              epochs = 100, 
#              batch_size = 64,
#              callbacks = [callback],
#              verbose = 0, 
#              validation_split = 0.25)

# %%
# best_paras = tuner.get_best_hyperparameters(num_trials = 1)[0]
# ANN = build_model(best_paras)

# %%
# ANN.fit(X_train, y_train, 
#         batch_size = 64, 
#         epochs = 100, 
#         callbacks = [callback], 
#         verbose = 0)
# ANN.summary()

# %%
# pred = ANN.predict(X_test)
# r2_score(y_test, pred)

# %%
# history = ANN.fit(X_train, 
#     y_train, 
#     epochs = 25, 
#     verbose = 0,
#     batch_size = 64, 
#     validation_split = 0.25)
