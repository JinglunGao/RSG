# %%
import numpy as np
import pandas as pd
import pickle
import gym
from google.colab import files
import tensorflow as tf
from tensorflow import keras

# https://github.com/openai/gym/tree/master/gym/spaces

# %%
# files.upload()

# %%
Call_model = tf.keras.models.load_model('2.5Call_LR0.0001.h5')
Call_data = pd.read_csv("Call_data.csv")
SPY = pd.read_csv("SPY.csv")

# %%
# pickle_in = open("scalerX.pickle","rb")
# scalerX = pickle.load(pickle_in)
# pickle_in = open("scalery.pickle","rb")
# scalery = pickle.load(pickle_in)

# %%
class OptionsTradingEnv(gym.Env):
    """
    An Options trading environment for OpenAI gym
    """
    # - human: render to the current display or terminal and return nothing. 
    # Usually for human consumption.
    metadata = {'render.modes': ['human']}

    def __init__(self, df1, df2):
        super(OptionsTradingEnv, self).__init__()
        self.df = df1
        self.contract_days = len(df1['START_DATE'].unique())
        self.days = df2['Date'].values
        self.underlying_asset_price = df2['Close'].values

    # private method
    def _next_observation(self): 
        if self.current_step < len(self.days):
            # Get the Options chain 
            observation = self.df[self.df['START_DATE'] == self.days[self.current_step]]
            self.observation = observation

            return observation
        else:
            return

    def _take_action(self, action):
        # # action in dict type with keys buy and sell
        # contracts_to_buy = action['Buy']
        # contracts_to_sell = action['Sell']
        if len(action) != 0:
            for i in range(len(action)):
                # Assume the bought price is the ask price
                options_price = self.observation['ASK'].iloc[action[i]]
                if self.balance >= options_price:
                    contract = {
                        'START_DATE': self.observation['START_DATE'].iloc[action[i]],
                        'END_DATE': self.observation['END_DATE'].iloc[action[i]],
                        'SKRIKE': self.observation['SKRIKE'].iloc[action[i]],
                        'ASK': options_price,
                        'OPTIONS_VALUE': self.underlying_asset_price[self.current_step] - self.observation['SKRIKE'].iloc[action[i]]
                    }
                    self.Bought_contracts.append(contract)
                    self.balance -= options_price

    def step(self, action):
        number_of_contracts = len(self.Bought_contracts)
        contracts_to_sell = []
        if number_of_contracts > 0:
            for i in range(number_of_contracts):
                # Profit for call options
                profit = max(0, self.underlying_asset_price[self.current_step] - self.Bought_contracts[i]['SKRIKE'])       
                self.Bought_contracts[i]['OPTIONS_VALUE'] = profit
                if self.Bought_contracts[i]['END_DATE'] == self.days[self.current_step]:
                    # This is at the expiration date
                    self.balance += profit
                    # Delete the contract from the list
                    contracts_to_sell.append(i)
                elif profit - self.Bought_contracts[i]['ASK'] > 0:
                    # Exercise the contract with probability ACT_RATE
                    if np.random.binomial(n = 1, p = self.act_rate) == 1:
                        self.balance += profit
                        contracts_to_sell.append(i)
 
        # Delete all the exercised contracts
        self.Bought_contracts = [self.Bought_contracts[i] for i in range(number_of_contracts) if i not in contracts_to_sell]
        # Calculate the net worth
        self.net_worth = self.balance + np.sum([self.Bought_contracts[i]['OPTIONS_VALUE'] for i in range(len(self.Bought_contracts))])

        done = self.net_worth <= 0

        # Execute one time step within the environment
        self._take_action(action)
        self.current_step += 1

        if self.current_step >= self.contract_days and len(self.Bought_contracts) == 0:
            print('We are done here')
            done = True
            return [], self.net_worth, done
        else:
            return self._next_observation(), self.net_worth, done

    def reset(self):
        # Reset the state of the environment to an initial state
        self.balance = INITIAL_ACCOUNT_BALANCE
        self.net_worth = INITIAL_ACCOUNT_BALANCE
        self.act_rate = ACT_RATE

        # Set the current step to 0
        self.current_step = 0
        self.Bought_contracts = []

        return self._next_observation()

    def render(self, mode = 'human', show = False):
        # Render the environment to the screen
        print('The current step is', self.current_step)
        print('Todays clos price is', self.underlying_asset_price[self.current_step])
        print('Hold contracts', self.Bought_contracts)
        print('The balance is', self.balance)
        print('The current net worth is', self.net_worth)
        print('-----------------------------------------------------------------------------------')

# %%
INITIAL_ACCOUNT_BALANCE = 1000
Features = ['UNDERLYING', 'SKRIKE', 'MATURITY', 'DELTA', 'BID', 'ASK', 'IMPLIED_VOL', 'LIQUIDITY', 'INTEREST_RATE']
ACT_RATE = 0.5
Env = OptionsTradingEnv(Call_data, SPY)
cur_state = Env.reset()
done = False
while not done:
    Env.render()
    if Env.current_step < Env.contract_days:
        # Predict the call options prices
        X = scalerX.transform(cur_state[Features].values)
        Options_price_pred = scalery.inverse_transform(Call_model.predict(X))
        # Buy undervalued call options
        price_diff = Options_price_pred.reshape(-1) - cur_state['ASK'].values
        if sum(price_diff > 0) > 5:
            action = np.argsort(price_diff)[::-1][:5]
        else:
            action = np.argsort(price_diff)[::-1][:sum(price_diff > 0)]
    else:
        action = []
    cur_state, NETWORTH, done = Env.step(action)
Env.render()
# Out:
# The current step is 0
# Todays clos price is 324.869995
# Hold contracts []
# The balance is 1000
# The current net worth is 1000
# -----------------------------------------------------------------------------------
# The current step is 1
# Todays clos price is 322.410004
# Hold contracts [{'START_DATE': '2020-01-02', 'END_DATE': '2020-01-28', 'SKRIKE': 165.0, 'ASK': 161.07, 'OPTIONS_VALUE': 159.86999500000002}, {'START_DATE': '2020-01-02', 'END_DATE': '2020-02-03', 'SKRIKE': 155.0, 'ASK': 170.9, 'OPTIONS_VALUE': 169.86999500000002}, {'START_DATE': '2020-01-02', 'END_DATE': '2020-01-28', 'SKRIKE': 185.0, 'ASK': 141.37, 'OPTIONS_VALUE': 139.86999500000002}, {'START_DATE': '2020-01-02', 'END_DATE': '2020-01-28', 'SKRIKE': 155.0, 'ASK': 170.95, 'OPTIONS_VALUE': 169.86999500000002}, {'START_DATE': '2020-01-02', 'END_DATE': '2020-01-27', 'SKRIKE': 160.0, 'ASK': 165.97, 'OPTIONS_VALUE': 164.86999500000002}]
# The balance is 189.7400000000001
# The current net worth is 1000.0
# -----------------------------------------------------------------------------------
# The current step is 2
# Todays clos price is 323.640015
# Hold contracts [{'START_DATE': '2020-01-02', 'END_DATE': '2020-01-28', 'SKRIKE': 165.0, 'ASK': 161.07, 'OPTIONS_VALUE': 157.41000400000001}, {'START_DATE': '2020-01-02', 'END_DATE': '2020-02-03', 'SKRIKE': 155.0, 'ASK': 170.9, 'OPTIONS_VALUE': 167.41000400000001}, {'START_DATE': '2020-01-02', 'END_DATE': '2020-01-28', 'SKRIKE': 185.0, 'ASK': 141.37, 'OPTIONS_VALUE': 137.41000400000001}, {'START_DATE': '2020-01-02', 'END_DATE': '2020-01-28', 'SKRIKE': 155.0, 'ASK': 170.95, 'OPTIONS_VALUE': 167.41000400000001}, {'START_DATE': '2020-01-02', 'END_DATE': '2020-01-27', 'SKRIKE': 160.0, 'ASK': 165.97, 'OPTIONS_VALUE': 162.41000400000001}, {'START_DATE': '2020-01-03', 'END_DATE': '2020-01-07', 'SKRIKE': 175.0, 'ASK': 148.6, 'OPTIONS_VALUE': 147.41000400000001}]
# The balance is 41.1400000000001
# The current net worth is 981.7900200000003
# -----------------------------------------------------------------------------------
# The current step is 3
# Todays clos price is 322.730011
# Hold contracts [{'START_DATE': '2020-01-02', 'END_DATE': '2020-01-28', 'SKRIKE': 165.0, 'ASK': 161.07, 'OPTIONS_VALUE': 158.640015}, {'START_DATE': '2020-01-02', 'END_DATE': '2020-02-03', 'SKRIKE': 155.0, 'ASK': 170.9, 'OPTIONS_VALUE': 168.640015}, {'START_DATE': '2020-01-02', 'END_DATE': '2020-01-28', 'SKRIKE': 185.0, 'ASK': 141.37, 'OPTIONS_VALUE': 138.640015}, {'START_DATE': '2020-01-02', 'END_DATE': '2020-01-28', 'SKRIKE': 155.0, 'ASK': 170.95, 'OPTIONS_VALUE': 168.640015}, {'START_DATE': '2020-01-02', 'END_DATE': '2020-01-27', 'SKRIKE': 160.0, 'ASK': 165.97, 'OPTIONS_VALUE': 163.640015}, {'START_DATE': '2020-01-06', 'END_DATE': '2020-01-17', 'SKRIKE': 175.0, 'ASK': 149.52, 'OPTIONS_VALUE': 148.640015}]
# The balance is 40.260015000000095
# The current net worth is 987.98009
# -----------------------------------------------------------------------------------
# The current step is 4
# Todays clos price is 324.450012
# Hold contracts [{'START_DATE': '2020-01-02', 'END_DATE': '2020-01-28', 'SKRIKE': 165.0, 'ASK': 161.07, 'OPTIONS_VALUE': 157.730011}, {'START_DATE': '2020-01-02', 'END_DATE': '2020-02-03', 'SKRIKE': 155.0, 'ASK': 170.9, 'OPTIONS_VALUE': 167.730011}, {'START_DATE': '2020-01-02', 'END_DATE': '2020-01-28', 'SKRIKE': 185.0, 'ASK': 141.37, 'OPTIONS_VALUE': 137.730011}, {'START_DATE': '2020-01-02', 'END_DATE': '2020-01-28', 'SKRIKE': 155.0, 'ASK': 170.95, 'OPTIONS_VALUE': 167.730011}, {'START_DATE': '2020-01-02', 'END_DATE': '2020-01-27', 'SKRIKE': 160.0, 'ASK': 165.97, 'OPTIONS_VALUE': 162.730011}, {'START_DATE': '2020-01-06', 'END_DATE': '2020-01-17', 'SKRIKE': 175.0, 'ASK': 149.52, 'OPTIONS_VALUE': 147.730011}]
# The balance is 40.260015000000095
# The current net worth is 981.640081
# -----------------------------------------------------------------------------------
# The current step is 5
# Todays clos price is 326.649994
# Hold contracts [{'START_DATE': '2020-01-02', 'END_DATE': '2020-01-28', 'SKRIKE': 165.0, 'ASK': 161.07, 'OPTIONS_VALUE': 159.45001200000002}, {'START_DATE': '2020-01-02', 'END_DATE': '2020-02-03', 'SKRIKE': 155.0, 'ASK': 170.9, 'OPTIONS_VALUE': 169.45001200000002}, {'START_DATE': '2020-01-02', 'END_DATE': '2020-01-28', 'SKRIKE': 185.0, 'ASK': 141.37, 'OPTIONS_VALUE': 139.45001200000002}, {'START_DATE': '2020-01-02', 'END_DATE': '2020-01-28', 'SKRIKE': 155.0, 'ASK': 170.95, 'OPTIONS_VALUE': 169.45001200000002}, {'START_DATE': '2020-01-02', 'END_DATE': '2020-01-27', 'SKRIKE': 160.0, 'ASK': 165.97, 'OPTIONS_VALUE': 164.45001200000002}, {'START_DATE': '2020-01-06', 'END_DATE': '2020-01-17', 'SKRIKE': 175.0, 'ASK': 149.52, 'OPTIONS_VALUE': 149.45001200000002}]
# The balance is 40.260015000000095
# The current net worth is 991.9600870000002
# -----------------------------------------------------------------------------------
# The current step is 6
# Todays clos price is 325.709991
# Hold contracts [{'START_DATE': '2020-01-02', 'END_DATE': '2020-02-03', 'SKRIKE': 155.0, 'ASK': 170.9, 'OPTIONS_VALUE': 171.649994}, {'START_DATE': '2020-01-02', 'END_DATE': '2020-01-28', 'SKRIKE': 155.0, 'ASK': 170.95, 'OPTIONS_VALUE': 171.649994}, {'START_DATE': '2020-01-02', 'END_DATE': '2020-01-27', 'SKRIKE': 160.0, 'ASK': 165.97, 'OPTIONS_VALUE': 166.649994}, {'START_DATE': '2020-01-09', 'END_DATE': '2020-01-13', 'SKRIKE': 180.0, 'ASK': 147.55, 'OPTIONS_VALUE': 146.649994}, {'START_DATE': '2020-01-09', 'END_DATE': '2020-01-16', 'SKRIKE': 175.0, 'ASK': 152.58, 'OPTIONS_VALUE': 151.649994}, {'START_DATE': '2020-01-09', 'END_DATE': '2020-01-21', 'SKRIKE': 170.0, 'ASK': 157.64, 'OPTIONS_VALUE': 156.649994}]
# The balance is 37.439997000000034
# The current net worth is 1005.159979
# -----------------------------------------------------------------------------------
# The current step is 7
# Todays clos price is 327.950012
# Hold contracts [{'START_DATE': '2020-01-02', 'END_DATE': '2020-02-03', 'SKRIKE': 155.0, 'ASK': 170.9, 'OPTIONS_VALUE': 170.709991}, {'START_DATE': '2020-01-02', 'END_DATE': '2020-01-28', 'SKRIKE': 155.0, 'ASK': 170.95, 'OPTIONS_VALUE': 170.709991}, {'START_DATE': '2020-01-02', 'END_DATE': '2020-01-27', 'SKRIKE': 160.0, 'ASK': 165.97, 'OPTIONS_VALUE': 165.709991}, {'START_DATE': '2020-01-09', 'END_DATE': '2020-01-13', 'SKRIKE': 180.0, 'ASK': 147.55, 'OPTIONS_VALUE': 145.709991}, {'START_DATE': '2020-01-09', 'END_DATE': '2020-01-16', 'SKRIKE': 175.0, 'ASK': 152.58, 'OPTIONS_VALUE': 150.709991}, {'START_DATE': '2020-01-09', 'END_DATE': '2020-01-21', 'SKRIKE': 170.0, 'ASK': 157.64, 'OPTIONS_VALUE': 155.709991}]
# The balance is 37.439997000000034
# The current net worth is 996.699943
# -----------------------------------------------------------------------------------
# The current step is 8
# Todays clos price is 327.450012
# Hold contracts [{'START_DATE': '2020-01-02', 'END_DATE': '2020-02-03', 'SKRIKE': 155.0, 'ASK': 170.9, 'OPTIONS_VALUE': 172.95001200000002}, {'START_DATE': '2020-01-02', 'END_DATE': '2020-01-28', 'SKRIKE': 155.0, 'ASK': 170.95, 'OPTIONS_VALUE': 172.95001200000002}, {'START_DATE': '2020-01-13', 'END_DATE': '2020-01-16', 'SKRIKE': 180.0, 'ASK': 148.77, 'OPTIONS_VALUE': 147.95001200000002}, {'START_DATE': '2020-01-13', 'END_DATE': '2020-01-24', 'SKRIKE': 175.0, 'ASK': 153.98, 'OPTIONS_VALUE': 152.95001200000002}, {'START_DATE': '2020-01-13', 'END_DATE': '2020-01-27', 'SKRIKE': 180.0, 'ASK': 149.09, 'OPTIONS_VALUE': 147.95001200000002}, {'START_DATE': '2020-01-13', 'END_DATE': '2020-01-27', 'SKRIKE': 175.0, 'ASK': 154.04, 'OPTIONS_VALUE': 152.95001200000002}]
# The balance is 58.36004500000013
# The current net worth is 1010.1400690000002
# -----------------------------------------------------------------------------------
# The current step is 9
# Todays clos price is 328.190002
# Hold contracts [{'START_DATE': '2020-01-02', 'END_DATE': '2020-02-03', 'SKRIKE': 155.0, 'ASK': 170.9, 'OPTIONS_VALUE': 172.45001200000002}, {'START_DATE': '2020-01-13', 'END_DATE': '2020-01-16', 'SKRIKE': 180.0, 'ASK': 148.77, 'OPTIONS_VALUE': 147.45001200000002}, {'START_DATE': '2020-01-13', 'END_DATE': '2020-01-24', 'SKRIKE': 175.0, 'ASK': 153.98, 'OPTIONS_VALUE': 152.45001200000002}, {'START_DATE': '2020-01-13', 'END_DATE': '2020-01-27', 'SKRIKE': 180.0, 'ASK': 149.09, 'OPTIONS_VALUE': 147.45001200000002}, {'START_DATE': '2020-01-13', 'END_DATE': '2020-01-27', 'SKRIKE': 175.0, 'ASK': 154.04, 'OPTIONS_VALUE': 152.45001200000002}, {'START_DATE': '2020-01-14', 'END_DATE': '2020-01-21', 'SKRIKE': 180.0, 'ASK': 148.34, 'OPTIONS_VALUE': 147.45001200000002}]
# The balance is 82.47005700000014
# The current net worth is 1003.0601170000002
# -----------------------------------------------------------------------------------
# The current step is 10
# Todays clos price is 330.920013
# Hold contracts [{'START_DATE': '2020-01-02', 'END_DATE': '2020-02-03', 'SKRIKE': 155.0, 'ASK': 170.9, 'OPTIONS_VALUE': 173.190002}, {'START_DATE': '2020-01-13', 'END_DATE': '2020-01-16', 'SKRIKE': 180.0, 'ASK': 148.77, 'OPTIONS_VALUE': 148.190002}, {'START_DATE': '2020-01-13', 'END_DATE': '2020-01-24', 'SKRIKE': 175.0, 'ASK': 153.98, 'OPTIONS_VALUE': 153.190002}, {'START_DATE': '2020-01-13', 'END_DATE': '2020-01-27', 'SKRIKE': 180.0, 'ASK': 149.09, 'OPTIONS_VALUE': 148.190002}, {'START_DATE': '2020-01-13', 'END_DATE': '2020-01-27', 'SKRIKE': 175.0, 'ASK': 154.04, 'OPTIONS_VALUE': 153.190002}, {'START_DATE': '2020-01-14', 'END_DATE': '2020-01-21', 'SKRIKE': 180.0, 'ASK': 148.34, 'OPTIONS_VALUE': 148.190002}]
# The balance is 82.47005700000014
# The current net worth is 1006.6100690000002
# -----------------------------------------------------------------------------------
# The current step is 11
# Todays clos price is 331.950012
# Hold contracts [{'START_DATE': '2020-01-02', 'END_DATE': '2020-02-03', 'SKRIKE': 155.0, 'ASK': 170.9, 'OPTIONS_VALUE': 175.92001299999998}, {'START_DATE': '2020-01-13', 'END_DATE': '2020-01-24', 'SKRIKE': 175.0, 'ASK': 153.98, 'OPTIONS_VALUE': 155.92001299999998}, {'START_DATE': '2020-01-13', 'END_DATE': '2020-01-27', 'SKRIKE': 180.0, 'ASK': 149.09, 'OPTIONS_VALUE': 150.92001299999998}, {'START_DATE': '2020-01-13', 'END_DATE': '2020-01-27', 'SKRIKE': 175.0, 'ASK': 154.04, 'OPTIONS_VALUE': 155.92001299999998}, {'START_DATE': '2020-01-16', 'END_DATE': '2020-01-21', 'SKRIKE': 185.0, 'ASK': 146.69, 'OPTIONS_VALUE': 145.92001299999998}, {'START_DATE': '2020-01-16', 'END_DATE': '2020-01-23', 'SKRIKE': 175.0, 'ASK': 156.74, 'OPTIONS_VALUE': 155.92001299999998}]
# The balance is 80.88008300000007
# The current net worth is 1022.990135
# -----------------------------------------------------------------------------------
# The current step is 12
# Todays clos price is 331.299988
# Hold contracts [{'START_DATE': '2020-01-02', 'END_DATE': '2020-02-03', 'SKRIKE': 155.0, 'ASK': 170.9, 'OPTIONS_VALUE': 176.95001200000002}, {'START_DATE': '2020-01-13', 'END_DATE': '2020-01-27', 'SKRIKE': 180.0, 'ASK': 149.09, 'OPTIONS_VALUE': 151.95001200000002}, {'START_DATE': '2020-01-16', 'END_DATE': '2020-01-23', 'SKRIKE': 175.0, 'ASK': 156.74, 'OPTIONS_VALUE': 156.95001200000002}, {'START_DATE': '2020-01-17', 'END_DATE': '2020-01-21', 'SKRIKE': 173.0, 'ASK': 159.8, 'OPTIONS_VALUE': 158.95001200000002}, {'START_DATE': '2020-01-17', 'END_DATE': '2020-01-21', 'SKRIKE': 177.0, 'ASK': 155.81, 'OPTIONS_VALUE': 154.95001200000002}, {'START_DATE': '2020-01-17', 'END_DATE': '2020-01-21', 'SKRIKE': 170.0, 'ASK': 162.78, 'OPTIONS_VALUE': 161.95001200000002}]
# The balance is 63.340119000000044
# The current net worth is 1027.580155
# -----------------------------------------------------------------------------------
# The current step is 13
# Todays clos price is 331.339996
# Hold contracts [{'START_DATE': '2020-01-13', 'END_DATE': '2020-01-27', 'SKRIKE': 180.0, 'ASK': 149.09, 'OPTIONS_VALUE': 151.29998799999998}, {'START_DATE': '2020-01-16', 'END_DATE': '2020-01-23', 'SKRIKE': 175.0, 'ASK': 156.74, 'OPTIONS_VALUE': 156.29998799999998}, {'START_DATE': '2020-01-21', 'END_DATE': '2020-01-27', 'SKRIKE': 174.0, 'ASK': 158.02, 'OPTIONS_VALUE': 157.29998799999998}, {'START_DATE': '2020-01-21', 'END_DATE': '2020-01-27', 'SKRIKE': 172.0, 'ASK': 160.08, 'OPTIONS_VALUE': 159.29998799999998}, {'START_DATE': '2020-01-21', 'END_DATE': '2020-01-27', 'SKRIKE': 176.0, 'ASK': 156.09, 'OPTIONS_VALUE': 155.29998799999998}, {'START_DATE': '2020-01-21', 'END_DATE': '2020-01-27', 'SKRIKE': 175.0, 'ASK': 157.09, 'OPTIONS_VALUE': 156.29998799999998}]
# The balance is 82.26007099999998
# The current net worth is 1021.140047
# -----------------------------------------------------------------------------------
# The current step is 14
# Todays clos price is 331.720001
# Hold contracts [{'START_DATE': '2020-01-16', 'END_DATE': '2020-01-23', 'SKRIKE': 175.0, 'ASK': 156.74, 'OPTIONS_VALUE': 156.33999599999999}, {'START_DATE': '2020-01-21', 'END_DATE': '2020-01-27', 'SKRIKE': 174.0, 'ASK': 158.02, 'OPTIONS_VALUE': 157.33999599999999}, {'START_DATE': '2020-01-21', 'END_DATE': '2020-01-27', 'SKRIKE': 172.0, 'ASK': 160.08, 'OPTIONS_VALUE': 159.33999599999999}, {'START_DATE': '2020-01-21', 'END_DATE': '2020-01-27', 'SKRIKE': 176.0, 'ASK': 156.09, 'OPTIONS_VALUE': 155.33999599999999}, {'START_DATE': '2020-01-21', 'END_DATE': '2020-01-27', 'SKRIKE': 175.0, 'ASK': 157.09, 'OPTIONS_VALUE': 156.33999599999999}, {'START_DATE': '2020-01-22', 'END_DATE': '2020-01-27', 'SKRIKE': 178.0, 'ASK': 154.27, 'OPTIONS_VALUE': 153.33999599999999}]
# The balance is 79.33006699999996
# The current net worth is 1018.3000469999998
# -----------------------------------------------------------------------------------
# The current step is 15
# Todays clos price is 328.769989
# Hold contracts [{'START_DATE': '2020-01-21', 'END_DATE': '2020-01-27', 'SKRIKE': 174.0, 'ASK': 158.02, 'OPTIONS_VALUE': 157.72000100000002}, {'START_DATE': '2020-01-21', 'END_DATE': '2020-01-27', 'SKRIKE': 172.0, 'ASK': 160.08, 'OPTIONS_VALUE': 159.72000100000002}, {'START_DATE': '2020-01-21', 'END_DATE': '2020-01-27', 'SKRIKE': 176.0, 'ASK': 156.09, 'OPTIONS_VALUE': 155.72000100000002}, {'START_DATE': '2020-01-21', 'END_DATE': '2020-01-27', 'SKRIKE': 175.0, 'ASK': 157.09, 'OPTIONS_VALUE': 156.72000100000002}, {'START_DATE': '2020-01-22', 'END_DATE': '2020-01-27', 'SKRIKE': 178.0, 'ASK': 154.27, 'OPTIONS_VALUE': 153.72000100000002}, {'START_DATE': '2020-01-23', 'END_DATE': '2020-01-27', 'SKRIKE': 172.0, 'ASK': 160.54, 'OPTIONS_VALUE': 159.72000100000002}]
# The balance is 75.51006799999999
# The current net worth is 1019.6500730000001
# -----------------------------------------------------------------------------------
# The current step is 16
# Todays clos price is 323.5
# Hold contracts [{'START_DATE': '2020-01-21', 'END_DATE': '2020-01-27', 'SKRIKE': 174.0, 'ASK': 158.02, 'OPTIONS_VALUE': 154.769989}, {'START_DATE': '2020-01-21', 'END_DATE': '2020-01-27', 'SKRIKE': 172.0, 'ASK': 160.08, 'OPTIONS_VALUE': 156.769989}, {'START_DATE': '2020-01-21', 'END_DATE': '2020-01-27', 'SKRIKE': 176.0, 'ASK': 156.09, 'OPTIONS_VALUE': 152.769989}, {'START_DATE': '2020-01-21', 'END_DATE': '2020-01-27', 'SKRIKE': 175.0, 'ASK': 157.09, 'OPTIONS_VALUE': 153.769989}, {'START_DATE': '2020-01-22', 'END_DATE': '2020-01-27', 'SKRIKE': 178.0, 'ASK': 154.27, 'OPTIONS_VALUE': 150.769989}, {'START_DATE': '2020-01-23', 'END_DATE': '2020-01-27', 'SKRIKE': 172.0, 'ASK': 160.54, 'OPTIONS_VALUE': 156.769989}]
# The balance is 75.51006799999999
# The current net worth is 1001.1300020000001
# -----------------------------------------------------------------------------------
# The current step is 17
# Todays clos price is 326.890015
# Hold contracts [{'START_DATE': '2020-01-27', 'END_DATE': '2020-01-31', 'SKRIKE': 172.0, 'ASK': 152.65, 'OPTIONS_VALUE': 151.5}, {'START_DATE': '2020-01-27', 'END_DATE': '2020-01-31', 'SKRIKE': 174.0, 'ASK': 150.51, 'OPTIONS_VALUE': 149.5}, {'START_DATE': '2020-01-27', 'END_DATE': '2020-01-31', 'SKRIKE': 173.0, 'ASK': 151.48, 'OPTIONS_VALUE': 150.5}, {'START_DATE': '2020-01-27', 'END_DATE': '2020-01-31', 'SKRIKE': 175.0, 'ASK': 149.64, 'OPTIONS_VALUE': 148.5}, {'START_DATE': '2020-01-27', 'END_DATE': '2020-01-31', 'SKRIKE': 176.0, 'ASK': 148.61, 'OPTIONS_VALUE': 147.5}]
# The balance is 216.62006800000006
# The current net worth is 969.510068
# -----------------------------------------------------------------------------------
# The current step is 18
# Todays clos price is 326.619995
# Hold contracts [{'START_DATE': '2020-01-27', 'END_DATE': '2020-01-31', 'SKRIKE': 172.0, 'ASK': 152.65, 'OPTIONS_VALUE': 154.890015}, {'START_DATE': '2020-01-27', 'END_DATE': '2020-01-31', 'SKRIKE': 173.0, 'ASK': 151.48, 'OPTIONS_VALUE': 153.890015}, {'START_DATE': '2020-01-27', 'END_DATE': '2020-01-31', 'SKRIKE': 175.0, 'ASK': 149.64, 'OPTIONS_VALUE': 151.890015}, {'START_DATE': '2020-01-28', 'END_DATE': '2020-02-03', 'SKRIKE': 173.0, 'ASK': 154.64, 'OPTIONS_VALUE': 153.890015}, {'START_DATE': '2020-01-28', 'END_DATE': '2020-02-03', 'SKRIKE': 174.0, 'ASK': 153.75, 'OPTIONS_VALUE': 152.890015}, {'START_DATE': '2020-01-28', 'END_DATE': '2020-02-03', 'SKRIKE': 176.0, 'ASK': 151.65, 'OPTIONS_VALUE': 150.890015}]
# The balance is 60.36009800000008
# The current net worth is 981.0701430000001
# -----------------------------------------------------------------------------------
# The current step is 19
# Todays clos price is 327.679993
# Hold contracts [{'START_DATE': '2020-01-27', 'END_DATE': '2020-01-31', 'SKRIKE': 172.0, 'ASK': 152.65, 'OPTIONS_VALUE': 154.61999500000002}, {'START_DATE': '2020-01-27', 'END_DATE': '2020-01-31', 'SKRIKE': 175.0, 'ASK': 149.64, 'OPTIONS_VALUE': 151.61999500000002}, {'START_DATE': '2020-01-28', 'END_DATE': '2020-02-03', 'SKRIKE': 173.0, 'ASK': 154.64, 'OPTIONS_VALUE': 153.61999500000002}, {'START_DATE': '2020-01-28', 'END_DATE': '2020-02-03', 'SKRIKE': 174.0, 'ASK': 153.75, 'OPTIONS_VALUE': 152.61999500000002}, {'START_DATE': '2020-01-28', 'END_DATE': '2020-02-03', 'SKRIKE': 176.0, 'ASK': 151.65, 'OPTIONS_VALUE': 150.61999500000002}, {'START_DATE': '2020-01-29', 'END_DATE': '2020-02-03', 'SKRIKE': 174.0, 'ASK': 153.4, 'OPTIONS_VALUE': 152.61999500000002}]
# The balance is 60.58009300000009
# The current net worth is 977.0800680000002
# -----------------------------------------------------------------------------------
# The current step is 20
# Todays clos price is 321.730011
# Hold contracts [{'START_DATE': '2020-01-27', 'END_DATE': '2020-01-31', 'SKRIKE': 172.0, 'ASK': 152.65, 'OPTIONS_VALUE': 155.67999300000002}, {'START_DATE': '2020-01-28', 'END_DATE': '2020-02-03', 'SKRIKE': 174.0, 'ASK': 153.75, 'OPTIONS_VALUE': 153.67999300000002}, {'START_DATE': '2020-01-28', 'END_DATE': '2020-02-03', 'SKRIKE': 176.0, 'ASK': 151.65, 'OPTIONS_VALUE': 151.67999300000002}, {'START_DATE': '2020-01-30', 'END_DATE': '2020-02-03', 'SKRIKE': 174.0, 'ASK': 154.49, 'OPTIONS_VALUE': 153.67999300000002}, {'START_DATE': '2020-01-30', 'END_DATE': '2020-02-03', 'SKRIKE': 173.0, 'ASK': 155.49, 'OPTIONS_VALUE': 154.67999300000002}, {'START_DATE': '2020-01-30', 'END_DATE': '2020-02-03', 'SKRIKE': 177.0, 'ASK': 151.38, 'OPTIONS_VALUE': 150.67999300000002}]
# The balance is 60.26007200000015
# The current net worth is 982.6600510000003
# -----------------------------------------------------------------------------------
# The current step is 21
# Todays clos price is 324.119995
# Hold contracts [{'START_DATE': '2020-01-28', 'END_DATE': '2020-02-03', 'SKRIKE': 174.0, 'ASK': 153.75, 'OPTIONS_VALUE': 147.730011}, {'START_DATE': '2020-01-28', 'END_DATE': '2020-02-03', 'SKRIKE': 176.0, 'ASK': 151.65, 'OPTIONS_VALUE': 145.730011}, {'START_DATE': '2020-01-30', 'END_DATE': '2020-02-03', 'SKRIKE': 174.0, 'ASK': 154.49, 'OPTIONS_VALUE': 147.730011}, {'START_DATE': '2020-01-30', 'END_DATE': '2020-02-03', 'SKRIKE': 173.0, 'ASK': 155.49, 'OPTIONS_VALUE': 148.730011}, {'START_DATE': '2020-01-30', 'END_DATE': '2020-02-03', 'SKRIKE': 177.0, 'ASK': 151.38, 'OPTIONS_VALUE': 144.730011}, {'START_DATE': '2020-01-31', 'END_DATE': '2020-02-04', 'SKRIKE': 171.0, 'ASK': 151.64, 'OPTIONS_VALUE': 150.730011}]
# The balance is 58.350083000000154
# The current net worth is 944.6401380000001
# -----------------------------------------------------------------------------------
# We are done here
# The current step is 22
# Todays clos price is 329.059998
# Hold contracts []
# The balance is 958.0700530000003
# The current net worth is 958.0700530000003
# -----------------------------------------------------------------------------------
